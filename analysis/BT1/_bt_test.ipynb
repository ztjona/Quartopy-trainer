# %%
# %load_ext autoreload
import sys
from pathlib import Path

sys.path.append(str(Path('../..').resolve()))

# %%
from utils import calculate_BradleyTerry

# %%
from collections import defaultdict
import pandas as pd

results = pd.DataFrame(
    [[0, 2, 0, 1], [3, 0, 5, 0], [0, 3, 0, 1], [4, 0, 3, 0]],
    columns=list("ABCD"),
    index=list("ABCD"),
)
results
# Out:
#    A  B  C  D
# A  0  2  0  1
# B  3  0  5  0
# C  0  3  0  1
# D  4  0  3  0

# %%
score = {"A": 1.0, "B": 1.0, "C": 1.0, "D": 1.0}
calculate_BradleyTerry(score, results, EPOCHS=5, normalize=True, verbose=True)
# Out:
# Calculating Bradley-Terry for 4 agents.
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Diff norm2: 0.315851
# ['0.516', '1.413', '0.672', '2.041']
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Diff norm2: 0.120455
# ['0.677', '1.034', '0.624', '2.287']
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Diff norm2: 0.010662
# ['0.650', '1.026', '0.656', '2.285']
# BT Epoch: 100%|██████████| 4/4 [00:00<00:00, 7674.85it/s]
# Diff norm2: 0.006190
# ['0.639', '1.042', '0.661', '2.271']
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# {'A': 0.6392126138691542,
#  'B': 1.044162645607778,
#  'C': 0.6601274693744127,
#  'D': 2.269649036214086}

# %%
score2 = {"A": 1.0, "B": 1.0, "C": 1.0, "D": 1.0}
calculate_BradleyTerry(score2, results, EPOCHS=5, normalize=False, verbose=True)
# Out:
# Calculating Bradley-Terry for 4 agents.
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Diff norm2: 0.254216
# ['0.429', '1.172', '0.557', '1.694']
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Diff norm2: 0.114341
# ['0.602', '0.919', '0.555', '2.033']
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Diff norm2: 0.015031
# ['0.567', '0.896', '0.573', '1.994']
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Diff norm2: 0.006919
# ['0.554', '0.905', '0.574', '1.971']
# BT Epoch: 100%|██████████| 4/4 [00:00<?, ?it/s]
# {'A': 0.5551672738018035,
#  'B': 0.9068734201894357,
#  'C': 0.5733321896074072,
#  'D': 1.9712296669098466}

# %%
2.269649036214086 / 1.9712296669098466
# Out:
# 1.1513874178710235

# %%
0.5551672738018035 * 1.1513
# Out:
# 0.6391640823280164

# %%
import numpy as np

# Extract the values from score and score2 dictionaries in the same order
keys = list(score.keys())
score_values = np.array([score[k] for k in keys])
score2_values = np.array([score2[k] for k in keys])

# Calculate the Pearson correlation coefficient
correlation = np.corrcoef(score_values, score2_values)
print("Correlation between score and score2:", correlation)
# Out:
# Correlation between score and score2: [[1. 1.]
#  [1. 1.]]
