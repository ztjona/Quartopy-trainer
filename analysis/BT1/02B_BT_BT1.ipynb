# %%
# %load_ext autoreload
import sys
from pathlib import Path

sys.path.append(str(Path('../..').resolve()))

# %%
import pandas as pd

results = pd.read_pickle("results_BT1.pkl")
results

# %%
for i, p in score.items():
    print(i, p)
# Out:
# -1 0.9997373182246694
# 0 1.008951487056233
# 1 1.0187405105291625
# 2 0.9636949540834612
# 3 0.9628875585277595
# 4 1.0121529694048685
# 5 0.9781252822461636
# 6 1.0338325970320736
# 7 1.0906498662942166
# 8 1.0629452473736811
# 9 1.1105788770610894
# 10 1.1416910498664943
# 11 1.210477409806553
# 12 1.1899297381184655
# 13 1.185707113260674
# 14 1.1857276832799224
# 15 1.1752727395448161
# 16 1.179913125207401
# 17 1.1299198358768683
# 18 1.1248797030512057
# 19 1.117700773257966
# 20 1.0475730751271775
# 21 1.0744178726703206
# 22 1.0348172509273128
# 23 1.029920678082085
# 24 1.01961301825453
# 25 1.0301347820014892
# 26 1.0458740784113052
# 27 1.0210717825279494
# 28 1.015589786139159
# 29 1.0099600008356924
# 30 1.0124943330950256
# 31 0.9995175816999607
# 32 1.0492469651659582
# 33 0.972173330663632
# 34 0.997962174307891
# 35 1.057843666861891
# 36 0.9977224999035342
# 37 1.0523793858304547
# 38 1.0123451834563804
# 39 0.9443007315466638
# 40 0.9858185384484028
# ...

# %%
from utils import calculate_BradleyTerry

# score = {i: 1.0 for i in range(-1, 7469)}
calculate_BradleyTerry(score, results, EPOCHS=3, normalize=True, verbose=True)
# Out:
# Calculating Bradley-Terry for 7470 agents.
# BT Epoch: 100%|██████████| 7470/7470 [10:03<00:00, 12.37it/s]
# {-1: 0.9999713616676448,
#  0: 1.0154467008127248,
#  1: 1.0273017287105848,
#  2: 0.969937312023237,
#  3: 0.9726980926072581,
#  4: 1.0184986090536061,
#  5: 0.9834933806021127,
#  6: 1.0390937109691134,
#  7: 1.0984659094088134,
#  8: 1.072032631669426,
#  9: 1.1182807070147345,
#  10: 1.1493339063386099,
#  11: 1.2200596360797673,
#  12: 1.196203952266375,
#  13: 1.193950413714957,
#  14: 1.1922707619466726,
#  15: 1.1827491936765355,
#  16: 1.1821304581761936,
#  17: 1.1322008816005242,
#  18: 1.12894356400125,
#  19: 1.1209825195345433,
#  20: 1.050762350686479,
#  21: 1.0797558490438548,
#  22: 1.04004588572149,
#  23: 1.0347880764739503,
#  24: 1.0238070334139004,
#  25: 1.034552074425988,
#  26: 1.0493273311276812,
#  27: 1.0263043819638284,
#  28: 1.019010799622324,
#  29: 1.0114719817460782,
#  30: 1.0137883021572407,
#  31: 1.0007216391202665,
# ...

# %%
score
# Out:
# {-1: 0.9999713616676448,
#  0: 1.0154467008127248,
#  1: 1.0273017287105848,
#  2: 0.969937312023237,
#  3: 0.9726980926072581,
#  4: 1.0184986090536061,
#  5: 0.9834933806021127,
#  6: 1.0390937109691134,
#  7: 1.0984659094088134,
#  8: 1.072032631669426,
#  9: 1.1182807070147345,
#  10: 1.1493339063386099,
#  11: 1.2200596360797673,
#  12: 1.196203952266375,
#  13: 1.193950413714957,
#  14: 1.1922707619466726,
#  15: 1.1827491936765355,
#  16: 1.1821304581761936,
#  17: 1.1322008816005242,
#  18: 1.12894356400125,
#  19: 1.1209825195345433,
#  20: 1.050762350686479,
#  21: 1.0797558490438548,
#  22: 1.04004588572149,
#  23: 1.0347880764739503,
#  24: 1.0238070334139004,
#  25: 1.034552074425988,
#  26: 1.0493273311276812,
#  27: 1.0263043819638284,
#  28: 1.019010799622324,
#  29: 1.0114719817460782,
#  30: 1.0137883021572407,
#  31: 1.0007216391202665,
#  32: 1.0520330454409648,
#  33: 0.9746733174699436,
#  34: 0.9998606716510692,
#  35: 1.060720802035649,
# ...

# %%
# import pickle

# with open("score_norm.pkl", "wb") as f:
#     pickle.dump(score, f)

# %%
import pickle

file = "p_i.pkl"

with open(file, "rb") as f:
    score_old = pickle.load(f)

# %%
score_df = pd.DataFrame({
    'score': pd.Series(score),
    'score_old': pd.Series(score_old),
}).sort_index()

score_df.head(18)
# Out:
#         score  score_old
# -1   0.999971   1.000293
#  0   1.015447   1.018218
#  1   1.027302   1.030234
#  2   0.969937   0.972524
#  3   0.972698   0.975480
#  4   1.018499   1.021247
#  5   0.983493   0.986182
#  6   1.039094   1.041904
#  7   1.098466   1.101382
#  8   1.072033   1.074930
#  9   1.118281   1.121064
#  10  1.149334   1.152562
#  11  1.220060   1.223169
#  12  1.196204   1.199618
#  13  1.193950   1.197173
#  14  1.192271   1.195400
#  15  1.182749   1.185927
#  16  1.182130   1.185059

# %%
import plotly.express as px

fig = px.scatter(
    score_df,
    x="score_old",
    y="score",
    title="Score vs Score Old",
    labels={"score_old": "Score Old", "score": "Score"},
    hover_name=score_df.index.astype(str),
)
# fig.add_shape(
#     type="line",
#     x0=score_df["score_old"].min(),
#     y0=score_df["score_old"].min(),
#     x1=score_df["score_old"].max(),
#     y1=score_df["score_old"].max(),
#     line=dict(color="gray", dash="dash"),
# )
fig.show()

# %%
correlation = score_df["score"].corr(score_df["score_old"])
print("Correlation between score and score_old:", correlation)
# Out:
# Correlation between score and score_old: 0.9999056640044457
