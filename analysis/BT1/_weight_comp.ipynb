# %%
import torch

f = "../../CHECKPOINTS/BT_1/20251017_1708-BT_1_epoch_0000.pt"
model = torch.load(f)

# %%
model.keys()
# Out:
# odict_keys(['fc_in_piece.weight', 'fc_in_piece.bias', 'conv1.weight', 'conv1.bias', 'conv2.weight', 'conv2.bias', 'fc1.weight', 'fc1.bias', 'fc2_board.weight', 'fc2_board.bias', 'fc2_piece.weight', 'fc2_piece.bias'])

# %%
w = []
for f in model:
    print(model[f].shape)
    w.append(model[f].flatten())
w = torch.cat(w)
w.shape
# Out:
# torch.Size([16, 16])
# torch.Size([16])
# torch.Size([16, 17, 3, 3])
# torch.Size([16])
# torch.Size([32, 16, 3, 3])
# torch.Size([32])
# torch.Size([128, 512])
# torch.Size([128])
# torch.Size([16, 128])
# torch.Size([16])
# torch.Size([16, 144])
# torch.Size([16])
# torch.Size([77424])

# %%
from torch.nn.utils import parameters_to_vector

all_params = parameters_to_vector([w for w in model.values()])
# Out:
# torch.Size([77424])

# %%
torch.all(all_params == w)
# Out:
# tensor(True)
