# %%
# %load_ext autoreload
import sys
from pathlib import Path


sys.path.append(str(Path('..').resolve()))
import os

if os.path.basename(os.getcwd()) == "tests":
    os.chdir("..")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from bot.CNN_F_bot import Quarto_bot as F_bot

bot = F_bot()
# Out:
# [10-17 11:25:46][INFO][CNN_F_bot.py] ✅ Model initialized with random weights

# %%
from quartopy import play_games

r, win_rate_p1 = play_games(
    matches=100,
    player1=bot,
    player2=bot,
    verbose=False,
    save_match=True,
    mode_2x2=True,
)
print(win_rate_p1)
# Out:
# Playing matches...:   0%|          | 0/100 [00:00<?, ?it/s]
# defaultdict(<function play_games.<locals>.<lambda> at 0x0000020EB0C147C0>, {'Player 2': 100})
