# %%
f = "C://Users//Laboratorio IA//Desktop//githubs//hierarchical-SAE//models//weights//QuartoCNN1//20250922_1248-EXP_id03_epoch_0010.pt"

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))
import os

if os.path.basename(os.getcwd()) == "tests":
    os.chdir("..")

# %%
from bot.CNN_bot import Quarto_bot

bot = Quarto_bot(model_path=f)

# %%
from bot.human import Quarto_bot as Human_bot

human = Human_bot()
human

# %%
from quartopy import play_games

_, win_rate_p1 = play_games(
    matches=1,
    player1=bot,
    player2=human,
    verbose=True,
    save_match=True,
    mode_2x2=True,
)
# Out:
# Playing matches...:   0%|          | 0/1 [00:00<?, ?it/s]
# (Player 1) [CNN_bot|20250922_1248-EXP_id03_epoch_0010.pt] SELECCIONA PIEZA ->(LKRN)
# Piezas en almacenamiento:
#     0      1      2      3      4      5      6      7
#   ╔══════╦══════╦══════╦══════╦══════╦══════╦══════╦══════╗
# 0 ║      ║ LKRH ║ LKQN ║ LKQH ║ LWRN ║ LWRH ║ LWQN ║ LWQH ║
#   ╠══════╬══════╬══════╬══════╬══════╬══════╬══════╬══════╣
# 1 ║ TKRN ║ TKRH ║ TKQN ║ TKQH ║ TWRN ║ TWRH ║ TWQN ║ TWQH ║
#   ╚══════╩══════╩══════╩══════╩══════╩══════╩══════╩══════╝
# (0, (0, 0))
# (1, (0, 1))
# (2, (0, 2))
# (3, (0, 3))
# (4, (1, 0))
# (5, (1, 1))
# (6, (1, 2))
# (7, (1, 3))
# (8, (2, 0))
# (9, (2, 1))
# (10, (2, 2))
# (11, (2, 3))
# (12, (3, 0))
# (13, (3, 1))
# (14, (3, 2))
# (15, (3, 3))
#
# (Player 2) [Human_bot] ========================================
# COLOCA PIEZA
# Tablero de juego:
#     0      1      2      3
#   ╔══════╦══════╦══════╦══════╗
# 0 ║ LKRN ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 1 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 2 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 3 ║      ║      ║      ║      ║
#   ╚══════╩══════╩══════╩══════╝
# (0, LKRH)
# (1, LKQN)
# (2, LKQH)
# (3, LWRN)
# (4, LWRH)
# (5, LWQN)
# (6, LWQH)
# (7, TKRN)
# (8, TKRH)
# (9, TKQN)
# (10, TKQH)
# (11, TWRN)
# (12, TWRH)
# (13, TWQN)
# (14, TWQH)
#
# (Player 2) [Human_bot] SELECCIONA PIEZA ->(LKRH)
# Piezas en almacenamiento:
#     0      1      2      3      4      5      6      7
#   ╔══════╦══════╦══════╦══════╦══════╦══════╦══════╦══════╗
# 0 ║      ║      ║ LKQN ║ LKQH ║ LWRN ║ LWRH ║ LWQN ║ LWQH ║
#   ╠══════╬══════╬══════╬══════╬══════╬══════╬══════╬══════╣
# 1 ║ TKRN ║ TKRH ║ TKQN ║ TKQH ║ TWRN ║ TWRH ║ TWQN ║ TWQH ║
#   ╚══════╩══════╩══════╩══════╩══════╩══════╩══════╩══════╝
#
# (Player 1) [CNN_bot|20250922_1248-EXP_id03_epoch_0010.pt] ========================================
# COLOCA PIEZA
# Tablero de juego:
#     0      1      2      3
#   ╔══════╦══════╦══════╦══════╗
# 0 ║ LKRN ║      ║ LKRH ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 1 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 2 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 3 ║      ║      ║      ║      ║
#   ╚══════╩══════╩══════╩══════╝
#
# (Player 1) [CNN_bot|20250922_1248-EXP_id03_epoch_0010.pt] SELECCIONA PIEZA ->(TKRN)
# Piezas en almacenamiento:
#     0      1      2      3      4      5      6      7
#   ╔══════╦══════╦══════╦══════╦══════╦══════╦══════╦══════╗
# 0 ║      ║      ║ LKQN ║ LKQH ║ LWRN ║ LWRH ║ LWQN ║ LWQH ║
#   ╠══════╬══════╬══════╬══════╬══════╬══════╬══════╬══════╣
# 1 ║      ║ TKRH ║ TKQN ║ TKQH ║ TWRN ║ TWRH ║ TWQN ║ TWQH ║
#   ╚══════╩══════╩══════╩══════╩══════╩══════╩══════╩══════╝
# (0, (0, 1))
# (1, (0, 3))
# (2, (1, 0))
# (3, (1, 1))
# (4, (1, 2))
# (5, (1, 3))
# (6, (2, 0))
# (7, (2, 1))
# (8, (2, 2))
# (9, (2, 3))
# (10, (3, 0))
# (11, (3, 1))
# (12, (3, 2))
# (13, (3, 3))
# [10-03 17:02:36][ERROR][human.py] Invalid input: invalid literal for int() with base 10: ''. Defaulting to first valid piece.
#
# (Player 2) [Human_bot] ========================================
# COLOCA PIEZA
# Tablero de juego:
#     0      1      2      3
#   ╔══════╦══════╦══════╦══════╗
# 0 ║ LKRN ║ TKRN ║ LKRH ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 1 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 2 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 3 ║      ║      ║      ║      ║
#   ╚══════╩══════╩══════╩══════╝
# (0, LKQN)
# (1, LKQH)
# (2, LWRN)
# (3, LWRH)
# (4, LWQN)
# (5, LWQH)
# (6, TKRH)
# (7, TKQN)
# (8, TKQH)
# (9, TWRN)
# (10, TWRH)
# (11, TWQN)
# (12, TWQH)
# [10-03 17:02:37][ERROR][human.py] Invalid input: invalid literal for int() with base 10: ''. Defaulting to first valid piece.
#
# (Player 2) [Human_bot] SELECCIONA PIEZA ->(LKQN)
# Piezas en almacenamiento:
#     0      1      2      3      4      5      6      7
#   ╔══════╦══════╦══════╦══════╦══════╦══════╦══════╦══════╗
# 0 ║      ║      ║      ║ LKQH ║ LWRN ║ LWRH ║ LWQN ║ LWQH ║
#   ╠══════╬══════╬══════╬══════╬══════╬══════╬══════╬══════╣
# 1 ║      ║ TKRH ║ TKQN ║ TKQH ║ TWRN ║ TWRH ║ TWQN ║ TWQH ║
#   ╚══════╩══════╩══════╩══════╩══════╩══════╩══════╩══════╝
#
# (Player 1) [CNN_bot|20250922_1248-EXP_id03_epoch_0010.pt] ========================================
# COLOCA PIEZA
# Tablero de juego:
#     0      1      2      3
#   ╔══════╦══════╦══════╦══════╗
# 0 ║ LKRN ║ TKRN ║ LKRH ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 1 ║      ║      ║ LKQN ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 2 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 3 ║      ║      ║      ║      ║
#   ╚══════╩══════╩══════╩══════╝
#
# (Player 1) [CNN_bot|20250922_1248-EXP_id03_epoch_0010.pt] SELECCIONA PIEZA ->(TWQH)
# Piezas en almacenamiento:
#     0      1      2      3      4      5      6      7
#   ╔══════╦══════╦══════╦══════╦══════╦══════╦══════╦══════╗
# 0 ║      ║      ║      ║ LKQH ║ LWRN ║ LWRH ║ LWQN ║ LWQH ║
#   ╠══════╬══════╬══════╬══════╬══════╬══════╬══════╬══════╣
# 1 ║      ║ TKRH ║ TKQN ║ TKQH ║ TWRN ║ TWRH ║ TWQN ║      ║
#   ╚══════╩══════╩══════╩══════╩══════╩══════╩══════╩══════╝
# (0, (0, 3))
# (1, (1, 0))
# (2, (1, 1))
# (3, (1, 3))
# (4, (2, 0))
# (5, (2, 1))
# (6, (2, 2))
# (7, (2, 3))
# (8, (3, 0))
# (9, (3, 1))
# (10, (3, 2))
# (11, (3, 3))
# [10-03 17:02:37][ERROR][human.py] Invalid input: invalid literal for int() with base 10: ''. Defaulting to first valid piece.
#
# (Player 2) [Human_bot] ========================================
# COLOCA PIEZA
# Tablero de juego:
#     0      1      2      3
#   ╔══════╦══════╦══════╦══════╗
# 0 ║ LKRN ║ TKRN ║ LKRH ║ TWQH ║
#   ╠══════╬══════╬══════╬══════╣
# 1 ║      ║      ║ LKQN ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 2 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 3 ║      ║      ║      ║      ║
#   ╚══════╩══════╩══════╩══════╝
# (0, LKQH)
# (1, LWRN)
# (2, LWRH)
# (3, LWQN)
# (4, LWQH)
# (5, TKRH)
# (6, TKQN)
# (7, TKQH)
# (8, TWRN)
# (9, TWRH)
# (10, TWQN)
# [10-03 17:02:39][ERROR][human.py] Invalid input: invalid literal for int() with base 10: ''. Defaulting to first valid piece.
#
# (Player 2) [Human_bot] SELECCIONA PIEZA ->(LKQH)
# Piezas en almacenamiento:
#     0      1      2      3      4      5      6      7
#   ╔══════╦══════╦══════╦══════╦══════╦══════╦══════╦══════╗
# 0 ║      ║      ║      ║      ║ LWRN ║ LWRH ║ LWQN ║ LWQH ║
#   ╠══════╬══════╬══════╬══════╬══════╬══════╬══════╬══════╣
# 1 ║      ║ TKRH ║ TKQN ║ TKQH ║ TWRN ║ TWRH ║ TWQN ║      ║
#   ╚══════╩══════╩══════╩══════╩══════╩══════╩══════╩══════╝
#
# (Player 1) [CNN_bot|20250922_1248-EXP_id03_epoch_0010.pt] ========================================
# COLOCA PIEZA
# Tablero de juego:
#     0      1      2      3
#   ╔══════╦══════╦══════╦══════╗
# 0 ║ LKRN ║ TKRN ║ LKRH ║ TWQH ║
#   ╠══════╬══════╬══════╬══════╣
# 1 ║      ║ LKQH ║ LKQN ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 2 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 3 ║      ║      ║      ║      ║
#   ╚══════╩══════╩══════╩══════╝
#
# ========================================
# ¡Player 1 [CNN_bot|20250922_1248-EXP_id03_epoch_0010.pt] ha ganado la partida!
# ========================================
