# %%
from quartopy import go_quarto
# Out:
# [05-26 13:35:38][INFO] 2025-05-26 13:35:38.489430
# Directorio de bots integrado: C:\Users\Laboratorio IA\Desktop\githubs\Quartopy\bot

# %%
go_quarto(1, "random_bot", "random_bot", 0, builtin_bots=True)
# Out:
# ================ INICIANDO TORNEO DE QUARTO ================
# [05-26 13:35:59][INFO] Iniciando torneo de Quarto con 1 partidas entre random_bot y random_bot
# [05-26 13:35:59][INFO] Usando bots integrados: random_bot y random_bot
#  Partidas: 1
#  Jugador 1: RandomBot
#  Jugador 2: RandomBot
#  Retardo: 0 segundos
#
#
# ======================= PARTIDA 1/1 ========================
#     0      1      2      3
#   ╔══════╦══════╦══════╦══════╗
# 0 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 1 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 2 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 3 ║      ║      ║      ║      ║
#   ╚══════╩══════╩══════╩══════╝
#
# ...
#  TURNO (Player 1): RandomBot
#  ACCIÓN:              SELECCIONAR PIEZA
# ...
#
#
# Player 1 (RandomBot) está seleccionando una pieza...
# Seleccionó la pieza: TALL, BLACK, CIRCLE, WITHOUT_HOLE
#
# === PIEZAS DISPONIBLES ===
#     0      1      2      3      4      5      6      7
# ...

# %%
go_quarto(
    1,
    "human",
    "random_bot",
    0,
    True,
    folder_bots="../bot/",
)
# Out:
# ================ INICIANDO TORNEO DE QUARTO ================
# [05-26 12:45:08][INFO] Iniciando torneo de Quarto con 1 partidas entre human y random_bot
# [05-26 12:45:08][INFO] Usando bots desde scripts: human y random_bot en la carpeta ../bot/
#  Partidas: 1
#  Jugador 1: Human_bot
#  Jugador 2: random_bot
#  Retardo: 0 segundos
#
#
# ======================= PARTIDA 1/1 ========================
#     0      1      2      3
#   ╔══════╦══════╦══════╦══════╗
# 0 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 1 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 2 ║      ║      ║      ║      ║
#   ╠══════╬══════╬══════╬══════╣
# 3 ║      ║      ║      ║      ║
#   ╚══════╩══════╩══════╩══════╝
#
# ...
#  TURNO (Player 1): random_bot
#  ACCIÓN:              SELECCIONAR PIEZA
# ...
#
#
# Player 1 (Human_bot) está seleccionando una pieza...
# (0, LKRN)
# (1, LKRH)
# (2, LKQN)
# (3, LKQH)
# (4, LWRN)
# (5, LWRH)
# (6, LWQN)
# (7, LWQH)
# (8, TKRN)
# (9, TKRH)
# ...
